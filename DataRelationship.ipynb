# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output/data.csv")
df.head()
# Out:
#   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 0         China      203334      2680         4776         51          169380
# 1           USA    82747175     38858      1018718        186        80506860
# 2         India    43062097      2011       522223          0        42523311
# 3        Brazil    30355919      6456       662777         76        29411813
# 4        France    28317915     13984       145257        197        26083461
#
#    NewRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  ...  \
# 0          2982        29178               274               141  ...
# 1         41509      1221597              1415            247359  ...
# 2          1970        16563               698             30658  ...
# 3         27459       281329              8318            140994  ...
# 4        202981      2089197              1677            432101  ...
#
#    TotalTests  Tests/1M pop  Population      Continent 1 Caseevery X ppl  \
# ...

# %% [markdown]
# # Câu 1: Tổng số ca nhiễm của 30 quốc gia nhiều nhất

# %%
total_df = df[['Country,Other', 'TotalCases', 'TotalDeaths', 'TotalRecovered']]
total_df = total_df.sort_values(by=['TotalCases'], ascending= False)
# figsize
fig, ax = plt.subplots(figsize=(14, 9))

ax.barh( total_df['Country,Other'][:30],total_df['TotalCases'][:30])

ax.set_title('Tống số ca nhiễm theo từng quốc gia', fontsize=32)
ax.set_xlabel('TotalCase', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# - Mỹ là quốc gia có số lượng ca nhiễm nhiều nhất thế giới, quá vượt trội so với phần còn lại của thế giới.
# - Tiếp theo là Ấn Độ với số lượng ca nhiễm bằng một nửa của Mỹ những cũng rất cao so với các quốc gia còn lại.
# - Đối với các quốc gia trong khu vực Đông Nam Á thì Việt Nam có tổng số ca nhiễm cao nhất, đây là một thống kê đáng buồn

# %% [markdown]
# # Câu 2: Tổng số ca chết của 30 quốc gia nhiều nhất

# %%
# figsize
fig, ax = plt.subplots(figsize=(14, 9))

total_df = total_df.sort_values(by=['TotalDeaths'], ascending= False)

# visualize
ax.barh( total_df['Country,Other'][:30],total_df['TotalDeaths'][:30])

ax.set_title('Tống số ca chết theo từng quốc gia', fontsize=32)
ax.set_xlabel('TotalDeaths', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# -  Mỹ là quốc gia có tổng số ca chết nhiều nhất thế giới và vượt trội hoàn toàn so với phần còn lại.
# - Brazil có tổng số ca nhiễm ít hơn Ấn Độ nhưng lại có số ca chết nhiều hơn Ấn Độ. Điều này cho thấy đội ngũ y tế của Brazil hoạt động không tốt bằng Ấn Độ.
# - Trong khu vực Đông Nam Á, Philippines là quốc gia có số lượng ca chết nhiều nhất, tiếp theo đó là Việt Nam.

# %% [markdown]
# # Câu 3: Tổng số ca hồi phục theo của quốc gia nhiều nhất (30 quốc gia có giá trị lớn nhất)

# %%
fig, ax = plt.subplots(figsize=(14, 9))

total_df = total_df.sort_values(by=['TotalRecovered'], ascending= False)

ax.barh( total_df['Country,Other'][:30],total_df['TotalRecovered'][:30])

ax.set_title('Tống số ca hồi phục theo từng quốc gia', fontsize=32)
ax.set_xlabel('TotalRecovered', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# - Mỹ vẫn là quốc gia có số lượng ca hồi phục nhiều nhất thế giới và nhiều gấp đôi so với quốc gia đứng thứ 2 là Ấn Độ.
# - Việt Nam là quốc gia có số lượng ca hồi phục nhiều nhất trong khu vực Đông Nam Á và cả châu Á.

# %% [markdown]
# # Câu 8: Tổng số ca nhiễm trên từng quốc gia trên 1 triệu dân số (30 quốc gia có giá trị lớn nhất)

# %%
fig, ax = plt.subplots(figsize=(14, 9))
toltal_per_1m = df[['Country,Other', 'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests']]

toltal_per_1m = toltal_per_1m.sort_values(by=['Tot Cases/1M pop'], ascending= False)

ax.barh( toltal_per_1m['Country,Other'][:30],toltal_per_1m['Tot Cases/1M pop'][:30])

ax.set_title('Tống số ca nhiễm theo từng quốc gia trên 1 triệu dân số', fontsize=32)
ax.set_xlabel('Tot Cases/1M pop', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# # Câu 9: Tổng số ca chết trên từng quốc gia trên 1 triệu dân số (30 quốc gia có giá trị lớn nhất)

# %%
fig, ax = plt.subplots(figsize=(14, 9))

toltal_per_1m = toltal_per_1m.sort_values(by=['Deaths/1M pop'], ascending= False)

ax.barh( toltal_per_1m['Country,Other'][:30],toltal_per_1m['Deaths/1M pop'][:30])

ax.set_title('Tống số ca chết theo từng quốc gia trên 1 triệu dân số', fontsize=32)
ax.set_xlabel('Deaths/1M pop', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# # Câu 10: Tổng số ca đã test trên từng quốc gia trên 1 triệu dân số (30 quốc gia có giá trị lớn nhất)

# %%
fig, ax = plt.subplots(figsize=(14, 9))
toltal_per_1m = df[['Country,Other', 'Tot Cases/1M pop', 'Deaths/1M pop', 'Tests/1M pop']]

toltal_per_1m = toltal_per_1m.sort_values(by=['Tests/1M pop'], ascending= False)

ax.barh( toltal_per_1m['Country,Other'][:30],toltal_per_1m['Tests/1M pop'][:30])

ax.set_title('Tống số ca hồi phục theo từng quốc gia', fontsize=32)
ax.set_xlabel('Tests/1M pop', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# # Câu x: Mối quan hệ giữa tổng số ca test và tổng số ca nhiễm

# %%
relation_test_case = df[['Country,Other', 'TotalCases', 'TotalTests']]
relation_test_case['total_per_test'] =  relation_test_case['TotalCases']/ relation_test_case['TotalTests']

relation_test_case = relation_test_case.sort_values(by=['total_per_test'], ascending= True)
# Out:
# <ipython-input-9-dbda41092122>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relation_test_case['total_per_test'] =  relation_test_case['TotalCases']/ relation_test_case['TotalTests']

# %%
fig, ax = plt.subplots(figsize=(14, 9))
ax.barh( relation_test_case['Country,Other'][:30],relation_test_case['total_per_test'][:30])

ax.set_title('Tỉ lệ số lượng ca nhiễm và số lượng ca test', fontsize=32)
ax.set_xlabel('total per test', fontsize=20)
ax.set_ylabel('Country', fontsize=20)
ax.tick_params(labelsize=14)

plt.show()
